# %%
import numpy as np

from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt

import easy21

# %%
# %matplotlib inline

env = easy21.BlackjackEnv()
agent = easy21.SarsaLambdaAgent(env, gamma=1, lmbda=0.2, N0=1280000)

K = 10000
Q = agent.learn(K)
A_ = np.argmax(Q, axis=3)
A = np.ones_like(A_)
while (not np.array_equal(A_, A)):
    A = A_
    K *= 2
    print('No. of episodes: {:}'.format(K))
    Q = agent.learn(K)
    A_ = np.argmax(Q, axis=3)

    plt.subplot(1,4,1)
    plt.title('Old Policy')
    plt.imshow(A[:,:,0].T, cmap='viridis')
    plt.xlabel('Player No Ace')
    plt.ylabel('Dealer State')
    plt.subplot(1,4,2)
    plt.imshow(A[:,:,1].T, cmap='viridis')
    plt.xlabel('Player /w Ace')
    plt.subplot(1,4,3)
    plt.title('New Policy')
    plt.imshow(A_[:,:,0].T, cmap='viridis')
    plt.xlabel('Player No Ace')
    plt.ylabel('Dealer State')
    plt.subplot(1,4,4)
    plt.imshow(A_[:,:,1].T, cmap='viridis')
    plt.xlabel('Player /w Ace')
    plt.show()
# Out:
# No. of episodes: 20000
# No. of episodes: 40000
# No. of episodes: 80000
# No. of episodes: 160000
# No. of episodes: 320000
# No. of episodes: 640000
# No. of episodes: 1280000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-efc3ae5aee84> in <module>()
#      12     K *= 2
#      13     print('No. of episodes: {:}'.format(K))
# ---> 14     Q = agent.learn(K)
#      15     A_ = np.argmax(Q, axis=3)
#      16
#
# ~\Documents\GitHub\ucl-dsilver-rl\easy21\SarsaLambdaAgent.py in learn(self, nEpisodes)
#      35                 r, s_ = self.env.step(s, a)
#      36                 self.N[s.index()+(a,)] += 1
# ---> 37                 a_ = self.selectAction(s_)
#      38
#      39                 q = self.Q[s.index()+(a,)]
#
# ~\Documents\GitHub\ucl-dsilver-rl\easy21\SarsaLambdaAgent.py in selectAction(self, s)
#      13     def selectAction(self, s):
#      14         epsilon = self.N0 / (self.N0 + np.sum(self.N[s.index()]))
# ---> 15         if np.random.rand() < (1 - epsilon):  # choose greedy action
#      16             a = np.argmax(self.Q[s.index()])
#      17         else:
#
# KeyboardInterrupt:

# %%
# %matplotlib inline

fig = plt.figure()
x = np.arange(1, 12)
y = np.arange(1, 22)
X, Y = np.meshgrid(x, y)

Z = agent.value()[:, :, 0].T[X, Y]
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='viridis')
ax.view_init(20, -20)
ax.set_xticks(np.arange(2, 12, 2))
ax.set_yticks(np.arange(2, 22, 2))
ax.set_xlabel('Dealer State')
ax.set_ylabel('Player State')
ax.set_zlabel('State Value')
ax.set_title('W/O Usable Ace')
plt.show()

Z = agent.value()[:, :, 1].T[X, Y]
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='viridis')
ax.view_init(20, -20)
ax.set_xticks(np.arange(2, 12, 2))
ax.set_yticks(np.arange(2, 22, 2))
ax.set_xlabel('Dealer State')
ax.set_ylabel('Player State')
ax.set_zlabel('State Value')
ax.set_title('With Usable Ace')
plt.show()

# %%
import seaborn as sns

sns.heatmap(Z.T, linewidths=.5, cmap='viridis', center=0.4)
